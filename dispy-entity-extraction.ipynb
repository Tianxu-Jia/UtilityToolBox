# %%
import dspy
import random
from dspy.datasets import DataLoader
from datasets import load_dataset

# Load the Banking77 dataset.
CLASSES = load_dataset("PolyAI/banking77", split="train", trust_remote_code=True).features['label'].names
kwargs = dict(fields=("text", "label"), input_keys=("text",), split="train", trust_remote_code=True)

# Load the first 2000 examples from the dataset, and assign a hint to each *training* example.
raw_data = [
    dspy.Example(x, label=CLASSES[x.label]).with_inputs("text")
    for x in DataLoader().from_huggingface(dataset_name="PolyAI/banking77", **kwargs)[:1000]
]

random.Random(0).shuffle(raw_data)
# Out:
# /home/txjia/.cache/huggingface/modules/datasets_modules/datasets/PolyAI--banking77/17ffc2ed47c2ed928bee64127ff1dbc97204cb974c2f980becae7c864007aed9/banking77.py:23: SyntaxWarning: invalid escape sequence '\~'
#   _CITATION = """\
# Downloading data: 100%|██████████| 839k/839k [00:00<00:00, 7.19MB/s]
# Downloading data: 100%|██████████| 240k/240k [00:00<00:00, 9.07MB/s]
# Generating train split: 100%|██████████| 10003/10003 [00:00<00:00, 117937.35 examples/s]
# Generating test split: 100%|██████████| 3080/3080 [00:00<00:00, 161172.46 examples/s]
# Average Metric: 3.00 / 17 (17.6%):  10%|█         | 21/200 [1:03:49<9:04:03, 182.36s/it]

# %%
raw_data
# Out:
# [Example({'text': 'What if there is an error on the exchange rate?', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'There must have been a mistake, why was I charged an extra pound?', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'If I find a card I lost do I need to dispose of it? Or can I re-active the card and continue to use it?', 'label': 'card_linking'}) (input_keys={'text'}),
#  Example({'text': 'The exchange rate for my electronic payment is incorrect.', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': "I'd lke my card reactivated, I was thinking it was misplaced but I discovered when I woke up that I had left it in my coat.", 'label': 'card_linking'}) (input_keys={'text'}),
#  Example({'text': 'How is the current exchange rate?', 'label': 'exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'A pending charge of 1L appears on my statement.  Please explain as I have not made a purchase for that amount', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'An item I bought had the wrong exchange rate applied.', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'I thought I would have received my new card at this point.', 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': "My new card isn't in my app, how do I get it in there?", 'label': 'card_linking'}) (input_keys={'text'}),
#  Example({'text': 'What fiat currencies are used for holdings?', 'label': 'fiat_currency_support'}) (input_keys={'text'}),
#  Example({'text': 'How can I tell what foreign exchange rate I will get?', 'label': 'exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'Hey, I have my card, how do I get it to show in the app?', 'label': 'card_linking'}) (input_keys={'text'}),
#  Example({'text': 'Which fiat currencies can I use through this app?', 'label': 'fiat_currency_support'}) (input_keys={'text'}),
#  Example({'text': 'What is the foreign exchange rate you will apply?', 'label': 'exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'I am being charged a pound out of nowhere. What is this?', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'What fiat currencies do you support?', 'label': 'fiat_currency_support'}) (input_keys={'text'}),
#  Example({'text': 'How come I was charged a transaction of $1?', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'How do I know what exchange rate I will get?', 'label': 'exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'When will my new card be delivered?', 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': 'I think the rate that was applied to my purchase using foreign currency is wrong. Help!', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'Should my cash withdrawal still be pending?', 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': 'What is the $1 transaction on my account?', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'Do you have info about the card on delivery?', 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': 'Why would a cash withdrawal still be pending?', 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': "Could I reactivate my card please, I couldn't find it but it turns out it was in my jacket pocket.", 'label': 'card_linking'}) (input_keys={'text'}),
#  Example({'text': 'How will I know what the exchange rate is?', 'label': 'exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'There is an extra $1 charge on my statement, why is that?', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'Where is the card I ordered 2 weeks ago?', 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': 'How can I periodically check the delivery of the card you sent?', 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': 'What is the source of your exchange rates?', 'label': 'exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'Last Saturday, I made a payment and the exchange rate was wrong.  I was charged too much.', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'I made an international purchase, but the exchange rate was wrong', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'My card was declined and I did not receive money from the ATM earlier, yet it show on my account that it is pending.', 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': 'I pulled cash from the ATM earlier. Why is it still pending if I already have the cash?', 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': '€1 was in my statement as an extra fee.', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': "I was issued a new card a week ago but still haven't received it. How long will it be until I receive it?", 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': "I tried to get some money but the machine was not working .The transaction still seems in progress! Can you please check what's going on.I don't want to be charged for money that I did not received.", 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': 'How does the exchange rate work?', 'label': 'exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'My cash withdrawal isnt showing on my account', 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': 'What currencies are supported?', 'label': 'fiat_currency_support'}) (input_keys={'text'}),
#  Example({'text': 'If I was travelling abroad, would I be able to hold currencies in euros?', 'label': 'fiat_currency_support'}) (input_keys={'text'}),
#  Example({'text': 'Is it possible to track the card you sent me?', 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': "I got a new card and can't find where to link it.", 'label': 'card_linking'}) (input_keys={'text'}),
#  Example({'text': 'Why does my statement show a $1 charge on my account?', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'I need to know what flat currencies you support for holding and exchange.', 'label': 'fiat_currency_support'}) (input_keys={'text'}),
#  Example({'text': 'I just checked my statement and saw a $1 charge, why is it there?', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'Are all European currencies available for holding and exchange?', 'label': 'fiat_currency_support'}) (input_keys={'text'}),
#  Example({'text': 'Can you tell me what this fee is on my statement?', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'What other fiat currencies can I use?', 'label': 'fiat_currency_support'}) (input_keys={'text'}),
#  Example({'text': 'Tell me the currencies that you support.', 'label': 'fiat_currency_support'}) (input_keys={'text'}),
#  Example({'text': 'How long does it take for cash withdrawals to hit my account?', 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': 'How can I add a new card?', 'label': 'card_linking'}) (input_keys={'text'}),
#  Example({'text': 'I have been charged way to much so something is apparently wrong with my exchange. I changed Russian Ruble into UK pounds.', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': "I didn't receive the correct exchange rate for an item that I bought.", 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': "The exchange rate you are using is really bad. This can't possibly be the official interbank exchange rate.", 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'How do you come up with your exchange rate', 'label': 'exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'I am still waiting for my card.', 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': 'My card never arrived.', 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': 'My statement shows an extra fee - what is it?', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': "I'm expecting to see a cash withdrawal but I'm still waiting.", 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': 'I have been charged a pound for something that appears on my statement', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'My foreign currency exchange has been applied incorrectly.', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'I bought an item and the exchange rate was wrong.', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'How much longer is it going to take to get my new card?', 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': 'I found my card in my jacket this morning, so can I reactivate it?', 'label': 'card_linking'}) (input_keys={'text'}),
#  Example({'text': 'Why is the exchange rate on my card payment different than I expected?', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'What is this €1 charge?', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'help me link my card', 'label': 'card_linking'}) (input_keys={'text'}),
#  Example({'text': 'Why does my account show as pending a cash withdrawal from the ATM that I have already made?', 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': 'I want to reactivate my card, I thought I had lost it but found it again in my jacket this morning.', 'label': 'card_linking'}) (input_keys={'text'}),
#  Example({'text': 'Can I track when my card will be delivered?', 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': 'My cash withdrawal is showing as pending, why?', 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': "I don't understand why there is an extra €1 fee in my statement.", 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'I would like to track a card sent to me, how do I do that?', 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': 'How do I make my card appear on the app?', 'label': 'card_linking'}) (input_keys={'text'}),
#  Example({'text': 'Why was I charged extra on my last UK pound to Russian ruble exchange?', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'The fee charged when I changed rubles into British pounds was too much.', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'My statement shows and extra 1$ that was charged to it and I would like to know why.', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'I need some help linking my new card.', 'label': 'card_linking'}) (input_keys={'text'}),
#  Example({'text': 'Can I get an update on my replacement card?', 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': 'I have withdrawn cash from the ATM but it is showing in my account as a pending transation. Why is this?', 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': 'I guess exchange rate for my payment was not correct, as i charged extra on the last saturday.', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': "I've been waiting a while for my card, is there a way to know when it will arrive?", 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': 'Can you tell me about why the account I have was charged an extra 1$', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'my cash withdrawal is pending, why?', 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': 'I am travelling and I was wondering what your exchange rates are', 'label': 'exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'What do i do if the exchange rate was wrong for the item i bought overseas?', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'Do you offer services that hold money in different types of currency?', 'label': 'fiat_currency_support'}) (input_keys={'text'}),
#  Example({'text': 'Can I re-link a lost card with the app?', 'label': 'card_linking'}) (input_keys={'text'}),
#  Example({'text': 'I bought an item at the wrong exchange rate.', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'My cash withdrawal shows pending, why?', 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': 'Please check the exchange rate for my payment last Saturday. I believe I have been overcharged.', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': "Why hasn't my withdrawal shown on my statement?", 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': 'Does my account have the option to hold multiple currencies?', 'label': 'fiat_currency_support'}) (input_keys={'text'}),
#  Example({'text': "Hello, I tried to take out some money out of the ATM, but it's still showing that it's pending? I really don't want to be charged for this.", 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': 'Why is my cash withdrawal still showing as pending?', 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': 'What is the fee on my statement for?', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'Where are you getting your exchange rates from?', 'label': 'exchange_rate'}) (input_keys={'text'}),
#  Example({'text': "Why is the exchange rate terrible?  That can't be close to the actual interbank rate.", 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'How long until my new card gets here?', 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': 'How do I add my card to the app once I get it?', 'label': 'card_linking'}) (input_keys={'text'}),
#  Example({'text': 'What foreign exchange rate will I get on weekdays and on the weekends?', 'label': 'exchange_rate'}) (input_keys={'text'}),
#  Example({'text': "2 weeks ago I ordered my new card.  It isn't here.  What should I do?", 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': 'I got a new card, how do I link it?', 'label': 'card_linking'}) (input_keys={'text'}),
#  Example({'text': 'Hello. I looked at my account and see that a transaction I tried to do is pending, but I did not complete that transaction. When I was at the ATM, the machine declined my card. Can you make sure that transaction does not go through because I definitely did not receive the money.', 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': 'I would like for someone to tell me which fiat currencies that your company supports.', 'label': 'fiat_currency_support'}) (input_keys={'text'}),
#  Example({'text': 'What is the extra €1 on my statement for?', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'It seems that something went wrong with my exchange. I changed Russian Ruble into UK pounds but have been charged entirely too much!', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'Why am I being charged more on exchange with things I bought abroad?', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'Is a tracking number available for the card that was just sent?', 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': "It's been a week since you sent my card and I still don't have it.", 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': 'I want to hold and exchange fiat currencies, what can I use to do so?', 'label': 'fiat_currency_support'}) (input_keys={'text'}),
#  Example({'text': "I tried to get cash at some ATM in the city centre earlier but the machine declined my card. I've seen it still shows up as pending in my account. Please cancel it immediately as I definitely have not received that money!", 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': 'Hello, I believe there has been a mistake made on the exchange rate for my card. Could you please check the official interbank exchange rate for me?', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'Do you know what your exchange rates are?', 'label': 'exchange_rate'}) (input_keys={'text'}),
#  Example({'text': "I'm still waiting for my new card.", 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': "I don't think the charges made when I had currency exchanged are right.", 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'Exchange rate on a purchase was incorrect', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'What is your opinion on the exchange rate?', 'label': 'exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'I had to pay a pound more than I anticipated!', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'I went to an ATM to get cash, but the app says the withdrawal is still pending. How is that possible when I already have the cash with me?', 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': 'How do I link one of your card that I already have?', 'label': 'card_linking'}) (input_keys={'text'}),
#  Example({'text': "Are you ripping people off with the exchange rate?  It can't be that atrocious between banks.", 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'How is the exchange rate calculated?', 'label': 'exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'Can my account have different types of currency in it.', 'label': 'fiat_currency_support'}) (input_keys={'text'}),
#  Example({'text': 'What are my options for holding money in multiple currencies?', 'label': 'fiat_currency_support'}) (input_keys={'text'}),
#  Example({'text': 'Why is your exchange rate different on different days?', 'label': 'exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'I did not receive the correct amount for the exchange rate.', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'There is an extra small charge on my card! What do I do?', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'How can I check on the delivery status of my card?', 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': 'There is a pending transaction on my account for when I tried to get money from the ATM earlier and it did not work. Can you fix this?', 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': 'Which currencies are allowed?', 'label': 'fiat_currency_support'}) (input_keys={'text'}),
#  Example({'text': 'Why is my cash withdrawal pending?', 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': 'How long will the $1 charge show as pending?', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': "Hello, I have a pending transaction in my account due to an ATM machine that wasn't working. In any case if the transaction goes through, after how long can I get my money back?", 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': 'Can I have money in more than one currency in my account?', 'label': 'fiat_currency_support'}) (input_keys={'text'}),
#  Example({'text': 'The exchange rate applied is wrong for my international purchase.', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'Can I reactivate a card?', 'label': 'card_linking'}) (input_keys={'text'}),
#  Example({'text': 'I exchanged Russian rubles for British pounds today and got less than I expected. Was exchange rate correct?', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'When will my cash withdrawal show/', 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': 'Can you tell me if I can track the card you sent me?', 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': 'What will my exchange rate be?', 'label': 'exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'What is the expected delivery date for my card?', 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': 'I would like to know which fiat currencies are recognized by your organization.', 'label': 'fiat_currency_support'}) (input_keys={'text'}),
#  Example({'text': "What's the reason my new card hasn't come?", 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': 'There seems to be an additional charge of £1 on my statement, what is the reason for this?', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'What exchange rate is it?', 'label': 'exchange_rate'}) (input_keys={'text'}),
#  Example({'text': "I took out money from the ATM and it's still showing as pending?", 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': 'In my statement, I got a €1 extra fee.', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'The amount of exchange was not correct for the item i bought.', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'How do I link the new card?', 'label': 'card_linking'}) (input_keys={'text'}),
#  Example({'text': "Why hasn't my card arrived yet?", 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': "How's the exchange rate looking right now?", 'label': 'exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'Can you tell me how to get my card on the app?', 'label': 'card_linking'}) (input_keys={'text'}),
#  Example({'text': 'In my account I noticed my ATM withdrawal is still pending', 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': 'How do you calculate exchange rates?', 'label': 'exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'why was i charged a small amount', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'Where is my card?', 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': 'How do I track the card you sent to me?', 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': 'Do you provide currency exchange to Euros?', 'label': 'fiat_currency_support'}) (input_keys={'text'}),
#  Example({'text': "Can you tell me why I haven't received my new card?", 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': 'How are the exchange rates determined?', 'label': 'exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'Why does my statement have an extra fee?', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'What currencies can I hold?', 'label': 'fiat_currency_support'}) (input_keys={'text'}),
#  Example({'text': 'I noticed an extra pound charge?', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': "I still haven't gotten my new card.  When will it get here?", 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': "I wasn't charged the correct exchange rate for an item I purchased.", 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'What is the system for determining the exchange rate?', 'label': 'exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'Can you make exchanges using the EUR?', 'label': 'fiat_currency_support'}) (input_keys={'text'}),
#  Example({'text': 'How do I see my card in the app?', 'label': 'card_linking'}) (input_keys={'text'}),
#  Example({'text': 'Can I have money of different country of origin.', 'label': 'fiat_currency_support'}) (input_keys={'text'}),
#  Example({'text': 'How do I get my cash withdrawal to show?', 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': 'Where can I link a new card?', 'label': 'card_linking'}) (input_keys={'text'}),
#  Example({'text': 'There is a withdrawal waiting.', 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': "Is my country's currency supported by your system?", 'label': 'fiat_currency_support'}) (input_keys={'text'}),
#  Example({'text': 'How do you do exchanges?', 'label': 'exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'What are you exchange rates?', 'label': 'exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'What can I do to track the card you sent me?', 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': 'Why was I charged more than I should have been?', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'There was a problem with the exchange rate on a purchase.', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'How do you determine the exchange rate?', 'label': 'exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'I am not seeing recent cash withdrawal on my account.', 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': 'I checked on google and the exchange rate you are using is really bad. Can you update it?', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'I have the cash already, my account still shows up as pending.  How can my account be still pending?', 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': 'What is this extra €1 fee about?', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': "There is a strange 1£ charge that appears as pending on my statement. What's the cause for that? I haven't purchased anything for a pound.", 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'The rate applied to my purchase in a foreign currency was wrong.', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'Could I get tracking on the card?', 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': "There's an extra fee on my statement, why is that?", 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': "I'm still waiting for my card that was issued a week ago. What should I do?", 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': 'How do I get my card into the app?', 'label': 'card_linking'}) (input_keys={'text'}),
#  Example({'text': "What is the status of my card's delivery?", 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': 'Is there a way to track the new card you sent me?', 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': 'Is the cash withdrawal going to show?', 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': 'I recently bought something abroad but the exchange rate is incorrect. Why?', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'Is it possible for me to track the card is was mailed to me?', 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': 'There is an extra 1£ charge on my app. Why did you charge me extra?', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'Do you have the best exchange rate?', 'label': 'exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'What does pending mean on a cash withdrawal?', 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': 'I think I may have been charged $1 extra on my app.  Could you provide some insight as to why this may have happened?', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'Why have I not gotten my new card?', 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': 'Which flat currencies can I use from you?', 'label': 'fiat_currency_support'}) (input_keys={'text'}),
#  Example({'text': 'What is the process to link the new card?', 'label': 'card_linking'}) (input_keys={'text'}),
#  Example({'text': 'What do I need to do to link my new card for my account?', 'label': 'card_linking'}) (input_keys={'text'}),
#  Example({'text': 'How do your exchange rates factor in?', 'label': 'exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'I was overcharged an additional pound.', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': "I needed cash today, so I used another provider's ATM, and when I attempted to withdraw, it declined. I just checked it out and I'm still showing my account with that amount pending! I didn't take any money out, it was declined, so I don't want that to be processed as a withdrawal.", 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': 'What is this fee debit on my account?', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'I removed cash from an ATM earlier but it shows up as pending in the app. How can this still be pending, I already received the cash?', 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': 'This exchange rate on my purchase is wrong.', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'What are your exchange rates calculated from?', 'label': 'exchange_rate'}) (input_keys={'text'}),
#  Example({'text': "I still haven't received my card after two weeks, is it lost?", 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': 'I recently purchased something, and the exchange rate was wrong.', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': "The exchange rate you're using is terrible - this can't be the official interbank exchange rate, can it?", 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'Can you do exchanges of EUR?', 'label': 'fiat_currency_support'}) (input_keys={'text'}),
#  Example({'text': 'I recently reported my card as missing/lost, and I just found it. Can I still use it?', 'label': 'card_linking'}) (input_keys={'text'}),
#  Example({'text': 'My cash withdrawal says pending, why?', 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': 'I changed the currency, but why is it costing more?', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'Was there a way for me to get tracking for that?', 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': 'Why has my withdrawal not posted?', 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': 'Does the exchange rate change?', 'label': 'exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'Cash withdrawal has been pending, why is it so?', 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': "I don't have my card after 1 week. What are my next steps?", 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': "I have one of your cards, but I don't know how to link it.", 'label': 'card_linking'}) (input_keys={'text'}),
#  Example({'text': 'I recently bought something in foreign currency and I am unsure of the exchange rate. Is this rate applied correctly?', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'Can you explain to me why a cash withdrawal shows up as pending?', 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': "I'm going on a trip soon and I needed to convert my Russian ruble to UK pounds, but when I did, your company charged me above the exchange rate. Did you mess up my transaction?", 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'I found my card, how can I use it again?', 'label': 'card_linking'}) (input_keys={'text'}),
#  Example({'text': "My card hasn't arrived in the mail yet. I ordered it two weeks ago. What can I do?", 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': 'How many currencies can I have money in in my account?', 'label': 'fiat_currency_support'}) (input_keys={'text'}),
#  Example({'text': 'Which currencies will you exchange?', 'label': 'fiat_currency_support'}) (input_keys={'text'}),
#  Example({'text': 'How do I track the card you sent me?', 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': 'I am inquiring about a $1 charge on my statement.', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'Where can I find the exchange rate for my transfer?', 'label': 'exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'Please explain the exchange rates.', 'label': 'exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'Can you tell me your exchange rates?', 'label': 'exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'Does the fee for exchange change?', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'I checked my account today and saw that I was charged an extra pound that I did not spend.', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': "Looking at my account I've noticed a charge that appears to still be in progress. I had attempted to get money out of the machine earlier but the machine seemed to have been broken. I never received my money so will you please look into this for me? I don't want to be charged for money I never actually received.", 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': 'What fiat money can I used in the exchange and holding?', 'label': 'fiat_currency_support'}) (input_keys={'text'}),
#  Example({'text': 'I noticed that the exchange rate applied to a recent purchase I made abroad was incorrect.', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'I would like to know what exchange rates you use?', 'label': 'exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'Why is it showing that my account has been charged a dollar that is showing as pending?', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'Why was my account assessed a fee?', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'What do I need to do to get my new card which I have requested 2 weeks ago?', 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': 'Why was I charged extra on my app?', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'I used foreign currency to buy something and I think the rate applied is incorrect.', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'Tell me your opinion on the exchange rate.', 'label': 'exchange_rate'}) (input_keys={'text'}),
#  Example({'text': "There is an odd 1£ charge that appears as pending on my statement. What's the reason for that? I haven't purchased anything for a pound.", 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'What is this extra pound charge for?', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'I already have a card and want to link it', 'label': 'card_linking'}) (input_keys={'text'}),
#  Example({'text': "Can you tell me why I haven't received my new card yet?", 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': 'The exchange rate was incorrect for an item I bought.', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'Your exchange rates are coming from where?', 'label': 'exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'Where in the app do I go to make my new card show up?', 'label': 'card_linking'}) (input_keys={'text'}),
#  Example({'text': 'Why is there an extra charge on my statement.', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'Is the exchange rate current?', 'label': 'exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'How long does it take to verify a cash withdraw?', 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': "Hey, I tried to withdraw some cash earlier and it's saying it's pending? Will I be charged for this?", 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': 'When will the cash that I put in the ATM be cleared from pending status?', 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': 'Why is there an extra fee charged?', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'How do I go forth on holding money in multiple currencies?', 'label': 'fiat_currency_support'}) (input_keys={'text'}),
#  Example({'text': 'How are exchange rates determined?', 'label': 'exchange_rate'}) (input_keys={'text'}),
#  Example({'text': "Why haven't I received my new card yet?", 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': 'What does it mean if my cash withdrawal does not show up properly?', 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': "My card hasn't came in the mail yet?", 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': 'How long does it take for a cash withdrawal to show?', 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': 'I got a card, how do I get it in the app?', 'label': 'card_linking'}) (input_keys={'text'}),
#  Example({'text': 'How do I add my new card?', 'label': 'card_linking'}) (input_keys={'text'}),
#  Example({'text': "There's an error in regards to the exchange rate for an item I bought.", 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'When did you send me my new card?', 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': 'My atm withdraw is stillpending', 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': 'How do I link an existing card?', 'label': 'card_linking'}) (input_keys={'text'}),
#  Example({'text': 'I would like to reactivate a card and wondered if that could be done?', 'label': 'card_linking'}) (input_keys={'text'}),
#  Example({'text': 'The card I thought I lost was in my jacket pocket this morning, so can I reactivate that?', 'label': 'card_linking'}) (input_keys={'text'}),
#  Example({'text': 'Why did a transaction I made charge me $1?', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'Are there any fiat currencies that you will not work with?', 'label': 'fiat_currency_support'}) (input_keys={'text'}),
#  Example({'text': "There has been a charge pending on my account statement that I can't figue out it's for a dollar.", 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'Which fiat currencies are supported for holding and exchanging?', 'label': 'fiat_currency_support'}) (input_keys={'text'}),
#  Example({'text': 'Why is my cash withdrawal still pending?', 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': 'How long will it be to get this new card?', 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': 'How do I add an existing card to the app?', 'label': 'card_linking'}) (input_keys={'text'}),
#  Example({'text': 'I found my card that I thought I had lost, I need to reactive it, please help.', 'label': 'card_linking'}) (input_keys={'text'}),
#  Example({'text': "I think I was charged extra on my payment on last Saturday.  Maybe the exchange rate was wrong?  I'd like a refund.", 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'Why did I get a $1 extra fee on the statement?', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'Its been several days and my cash withdrawal is still pending. Why?', 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': "Is there a reason there's an extra fee on my statement?", 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'In my statement, there was an extra €1 fee', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'My purchase used the wrong exchange rate', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'What currencies are available for my use in holding and exchange?', 'label': 'fiat_currency_support'}) (input_keys={'text'}),
#  Example({'text': 'A card has been sent to me, how do I track it?', 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': 'I see an extra $1\xa0 charge on my statement, why is this?', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'Is it possible to hold money in different currencies?', 'label': 'fiat_currency_support'}) (input_keys={'text'}),
#  Example({'text': 'Which fiat currencies are compatible for exchange and holding?', 'label': 'fiat_currency_support'}) (input_keys={'text'}),
#  Example({'text': 'I seem to have been charged to much for my holiday purchases, the exchange rate is wrong.', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'the exchange rate is wrong from something I got in another country', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'I have a card that was deactivated can I reactivate it?', 'label': 'card_linking'}) (input_keys={'text'}),
#  Example({'text': 'An incorrect exchange rate was applied to an item I bought.', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'I ordered a card and would like to know how to track the delivery progress of it.', 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': "I know I'm getting a new card but would like know when I can expect to receive it.", 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': "I just got my card.  It's not linked yet--how do I do that?", 'label': 'card_linking'}) (input_keys={'text'}),
#  Example({'text': 'Hello. I have a transaction in my account listed as pending. I tried to use an ATM at the city centre, but the machine declined my card, and I did not receive the money. Why is the transaction still pending if I did not receive the money.', 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': 'I took out some cash from the ATM but it is still showing the transaction is pending.', 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': 'There is a charge for 1£ on my statement.  I do not think that I bought anything that costed 1£.  What is going on?', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'Why is there an extra €1 fee in my statement?', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'Can you let me know why my cash withdrawal is still pending?', 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': 'I think that the exchange rate was wrong for the payment made last Saturday - I was charged extra.', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': "I was issued a card about a week ago. why hasn't it come in yet?", 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': 'What is my money worth in other countries?', 'label': 'exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'where do you find your exchange rates?', 'label': 'exchange_rate'}) (input_keys={'text'}),
#  Example({'text': "The correct exchange rate wasn't given to me for an item I purchased.", 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': "I've been charged an extra £1 and I don't know what it's for", 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'How does the exchange rate work on this app?', 'label': 'exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'Why does it still charge me even though I was unable to withdraw money from the ATM?', 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': 'I bought something in another currency, but the exchange rate was incorrect.', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': "On my statement, there is a strange 1£ charge that appears as pending. What's causing that? I haven't purchased anything that's just a pound.", 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'I purchased something abroad but the exchange rate is incorrect.', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'Why is there an extra charge of 1 dollar on my statement?', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'Where do I scan my card?', 'label': 'card_linking'}) (input_keys={'text'}),
#  Example({'text': 'Will you work with any fiat currencies?', 'label': 'fiat_currency_support'}) (input_keys={'text'}),
#  Example({'text': 'Why is my exchange rate wrong?', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'Can you change my currency to EUR?', 'label': 'fiat_currency_support'}) (input_keys={'text'}),
#  Example({'text': 'Can I put my old card back in the app?', 'label': 'card_linking'}) (input_keys={'text'}),
#  Example({'text': 'I got billed an extra pound!', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': "Shouldn't my new card be here by now?", 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': 'After purchasing an item I noticed the exchange rate was incorrect.', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'Why is the exchange rate on my card wrong?', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'How can I solve my issue with holding multiple currencies?', 'label': 'fiat_currency_support'}) (input_keys={'text'}),
#  Example({'text': 'I believe you charged me too much to exchange my money', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'Can you explain your exchange rates basis?', 'label': 'exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'My card appears to have never arrived?', 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': 'Do I have a $1 extra fee on the statement?', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'What does it mean when a cash withdrawal is pending?', 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': 'I tried to withdraw cash at an ATM in the city center but my card was declined. The transaction is still showing up as pending - please cancel it!', 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': 'How can I make my card show up in the app?', 'label': 'card_linking'}) (input_keys={'text'}),
#  Example({'text': 'What currencies do you support?', 'label': 'fiat_currency_support'}) (input_keys={'text'}),
#  Example({'text': 'What are the current exchange rates?', 'label': 'exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'How do I add my new card to the app?', 'label': 'card_linking'}) (input_keys={'text'}),
#  Example({'text': 'My card payment had the wrong exchange rate', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'Is there a tracking number for the card you sent me?', 'label': 'card_arrival'}) (input_keys={'text'}),
# ...
#  Example({'text': '$1 charge in transaction.', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'What fiat currencies can I use for holding and exchanging?', 'label': 'fiat_currency_support'}) (input_keys={'text'}),
#  Example({'text': 'Why did you charge me extra?', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'Please tell me the types of currency I can hold.', 'label': 'fiat_currency_support'}) (input_keys={'text'}),
#  Example({'text': 'Now that I have my card, how do I connect it to the app?', 'label': 'card_linking'}) (input_keys={'text'}),
#  Example({'text': 'My rate of exchange was wrong.', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'How is my ATM deposit not available yet?', 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': 'What are the exchange rates you assign?', 'label': 'exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'The exchange rate is bad. Are you sure this is the exchange rate?', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'Am I able to track a card that has already been sent?', 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': 'I had to pay one pound more than the set price!', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'I would like to know how exchange rates are calculated when transferring funds.', 'label': 'exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'I was charged extra. Was the exchange rate for my payment last Saturday wrong?', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': "What's the process for exchanges?", 'label': 'exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'Can you please tell me where my card is? I ordered it 2 weeks ago!', 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': "The exchange rate you are using is really bad.This can't be the official interbank exchange rate.", 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'Why was the exchange wrong for the item I purchased?', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'Can you convert to EUR?', 'label': 'fiat_currency_support'}) (input_keys={'text'}),
#  Example({'text': 'What are Interbanks current exchange rates?', 'label': 'exchange_rate'}) (input_keys={'text'}),
#  Example({'text': "How can I track my card's delivery?", 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': 'WHAT IS THE SOLUTION OF THIS PROBLEM', 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': 'The currency exchange rate was wrong for a purchase I made.', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'A foreign purchase I made has the incorrect rate applied to it.', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'What fiat currencies do you allow exchange with?', 'label': 'fiat_currency_support'}) (input_keys={'text'}),
#  Example({'text': "Why haven't I gotten my new card?", 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': 'my cash out is still pending', 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': 'Is there a way to link cards if I have one of yours?', 'label': 'card_linking'}) (input_keys={'text'}),
#  Example({'text': 'I would like to link my card to my account.', 'label': 'card_linking'}) (input_keys={'text'}),
#  Example({'text': "Have have a small charge on my account from someone I purchased with but I'm not sure what it relates to.", 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'I found my lost card. Am I still able to use it?', 'label': 'card_linking'}) (input_keys={'text'}),
#  Example({'text': "I haven't gotten my new card.", 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': 'Do you convert to Euro?', 'label': 'fiat_currency_support'}) (input_keys={'text'}),
#  Example({'text': 'Please explain the charge of 1L in error.  I have purchased nothing in this amount.', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'How do you find the exchange rate?', 'label': 'exchange_rate'}) (input_keys={'text'}),
#  Example({'text': "I'm interested in holding and exchange for flat currencies, what do you support?", 'label': 'fiat_currency_support'}) (input_keys={'text'}),
#  Example({'text': 'Card has been received, how will it show up on the app?', 'label': 'card_linking'}) (input_keys={'text'}),
#  Example({'text': 'How do you determine exchange rates?', 'label': 'exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'How many currencies can I have?', 'label': 'fiat_currency_support'}) (input_keys={'text'}),
#  Example({'text': "I tried to take out some money from an ATM earlier today and it was declined. Looking on my screen now, I still see that it's pending for that amount. I didn't actually get that money, so I don't want it processed on my account.", 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': 'Why was the wrong rate applied when I bought something in a different currency?', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'What is the extra fee on my statement?', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': "What can I do if my card still hasn't arrived after 2 weeks?", 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': 'I was made to pay an additional pound!', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'Hello, I see that I have been charged an extra $1 on my app.  Could you please provide me with a reason for this charge?', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'i withdrew cash and dont see it reflected on the balance', 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': 'Is there any reason my cash withdrawal still shows as pending?', 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': 'I do not understand why there is a pending 1£ charge on my statement, I do not recall making this transaction. Can you please tell me what this is about?', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'Can you please explain why the exchange rate for the item I bought is wrong?', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'I tried to withdraw money, but was unable to. Still says that the transaction is pending? Will this money disappear??', 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': 'An extra fee of €1 was in my statement', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'Can you help me track my card?', 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': "It's been a week since I ordered my card and it's not here. Please help?", 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': 'I purchased an item and the exchange rate was wrong', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'What does it mean if my cash withdrawal is pending?', 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': 'Can I track the card you sent to me?', 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': 'Where do I go to get my new card linked?', 'label': 'card_linking'}) (input_keys={'text'}),
#  Example({'text': 'I am not receiving the correct exchange rate on my card.', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'What currencies can I have?', 'label': 'fiat_currency_support'}) (input_keys={'text'}),
#  Example({'text': 'I bough an item and the exchange rate was incorrect.', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'What fiat currencies are supported?', 'label': 'fiat_currency_support'}) (input_keys={'text'}),
#  Example({'text': 'The exchange rate that was applied for an international purchase was wrong.', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'How do I add the card I just received to show up in the app?', 'label': 'card_linking'}) (input_keys={'text'}),
#  Example({'text': 'What flat currencies do you support for holding and exchange?', 'label': 'fiat_currency_support'}) (input_keys={'text'}),
#  Example({'text': 'Why did I get charged one pound seemingly randomly?', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'I got a €1 extra fee in my statement', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'How do you decide what the exchange rates are?', 'label': 'exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'Why is your exchange rate so bad?', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': "I'd like to know what the foreign exchange rate will be.", 'label': 'exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'When will my new card arrive?', 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': 'Why is there a 1 euro fee on my statement?', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'It seems that the rate I got is incorrect.', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'What is an exchange rate?', 'label': 'exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'How come there is an extra fee on my statement?', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': "I tempted to get some money out of the machine earlier and it did not work.Looking now, the transaction actually shows to still be in progress. I would certainly appreciate someone look into this and let me know what's going on. I definitely do not want to be charged for money I never received.", 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': 'Are there limitations to what currency I can hold?', 'label': 'fiat_currency_support'}) (input_keys={'text'}),
#  Example({'text': 'How long will it take for me to get my card?', 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': "My account shows up as pending after I received cash from the ATM earlier.  How can this be still pending? I've got the cash already.", 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': "I have not received my card and it's been a week, what do I do?", 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': "How's the exchange rate?", 'label': 'exchange_rate'}) (input_keys={'text'}),
#  Example({'text': "My card still hasn't arrived after two weeks, now what?", 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': 'What fiat currencies are used with holdings and exchanges?', 'label': 'fiat_currency_support'}) (input_keys={'text'}),
#  Example({'text': 'I am seeing and extra 1$ charged to my account and wanted to know about it.', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'How long will a cash withdrawal be pending?', 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': 'What is this random charge of one pound doing on my account?', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'I am being charged the wrong amount on my card.', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'What kind of money can I hold?', 'label': 'fiat_currency_support'}) (input_keys={'text'}),
#  Example({'text': 'Can I put my found card back into the app on my phone?', 'label': 'card_linking'}) (input_keys={'text'}),
#  Example({'text': "I'm concerned because my cash withdrawal is pending.", 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': 'I was overcharged one extra pound!', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': "Is there a reason my new card hasn't arrived?", 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': "So much time has gone by, the pending status shouldn't still be there shouldn't it?", 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': "I was supposed to receive my new card by now, but it hasn't came in.", 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': 'if i found a lost card can i put it back in app', 'label': 'card_linking'}) (input_keys={'text'}),
#  Example({'text': "My new card isn't here and it was issued a week ago.", 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': 'Are you sure this is the interbank exchange rate? This rate is really bad.', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'In the app, how can I make it show the new card that arrived?', 'label': 'card_linking'}) (input_keys={'text'}),
#  Example({'text': 'Do you support fiat currencies?', 'label': 'fiat_currency_support'}) (input_keys={'text'}),
#  Example({'text': 'Am I allowed to hold money in multiple currencies?', 'label': 'fiat_currency_support'}) (input_keys={'text'}),
#  Example({'text': 'My statement contained a one pound extra fee', 'label': 'extra_charge_on_statement'}) (input_keys={'text'}),
#  Example({'text': 'How do I know what the exchange rate will be when I make an exchange.', 'label': 'exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'I have been overcharged. I just changed over Russian Ruble to UK pounds and it was too much. It seems something was wrong with my exchange.', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'How are exchange rates calculated at this bank?', 'label': 'exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'Why is my cash still pending that I put in ATM?', 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': 'My cash withdrawal shows as pending still.', 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': 'What fiduciary currencies are supported for tenure and exchange?', 'label': 'fiat_currency_support'}) (input_keys={'text'}),
#  Example({'text': 'the exchange rate on my payment was wrong', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'The exchange rate given to me after a purchase, was incorrect', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'I have been charged to much for the object I bought when abroad, the exchange rate seems to be wrong.', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'Do you have EUR currency available for me?', 'label': 'fiat_currency_support'}) (input_keys={'text'}),
#  Example({'text': 'How do I reactivate my card?', 'label': 'card_linking'}) (input_keys={'text'}),
#  Example({'text': 'Where is my credit card that was to be mailed?', 'label': 'card_arrival'}) (input_keys={'text'}),
#  Example({'text': 'The exchange rate is incorrect for my payment.', 'label': 'card_payment_wrong_exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'Can you tell me how many currencies I can hold?', 'label': 'fiat_currency_support'}) (input_keys={'text'}),
#  Example({'text': 'Why do I still have a pending cash withdrawal?', 'label': 'pending_cash_withdrawal'}) (input_keys={'text'}),
#  Example({'text': "I'd like to know what you guys look at to decide an exchange rate", 'label': 'exchange_rate'}) (input_keys={'text'}),
#  Example({'text': 'I Withdrew cash from an ATM earlier but it shows up as pending in the app. How can this still be pending, I received the cash already?', 'label': 'pending_cash_withdrawal'}) (input_keys={'text'})]

# %%
len(CLASSES), CLASSES[:10]
# Out:
# (77,
#  ['activate_my_card',
#   'age_limit',
#   'apple_pay_or_google_pay',
#   'atm_support',
#   'automatic_top_up',
#   'balance_not_updated_after_bank_transfer',
#   'balance_not_updated_after_cheque_or_cash_deposit',
#   'beneficiary_not_allowed',
#   'cancel_transfer',
#   'card_about_to_expire'])

# %%
unlabeled_trainset = [dspy.Example(text=x.text).with_inputs("text") for x in raw_data[:500]]

unlabeled_trainset[0]
# Out:
# Example({'text': 'What if there is an error on the exchange rate?'}) (input_keys={'text'})

# %%
from typing import Literal

classify = dspy.ChainOfThought(f"text -> label: Literal{CLASSES}")
